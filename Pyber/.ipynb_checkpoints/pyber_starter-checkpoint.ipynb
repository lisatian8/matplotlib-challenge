# %%
# %matplotlib notebook

# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import pandas as pd
import numpy as np
import os
import csv


# File to Load (Remember to change these)
city_data_to_load = "./data/city_data.csv"
ride_data_to_load = "./data/ride_data.csv"

# Read the City and Ride Data

city_data = pd.read_csv(city_data_to_load)
#city_data.head()
df_city_data = pd.DataFrame(city_data)
print(f'lenth of city data: {len(df_city_data)}')

df_city_data.drop_duplicates(subset=None, keep='first', inplace=True)
print(f'lenth of city data  now: {len(df_city_data)}')

df_city_data.head()
df_city_data_for_type = pd.DataFrame(df_city_data)
df_city_data_for_color = pd.DataFrame(df_city_data)
df_city_data_for_type_driver = pd.DataFrame(df_city_data)
df_city_data_for_bubble = pd.DataFrame(df_city_data)

ride_data = pd.read_csv(ride_data_to_load)
df_ride_data = pd.DataFrame(ride_data)  
print(f'lenth of ride data: {len(df_ride_data)}')

df_ride_data.drop_duplicates(subset=None, keep='first', inplace=True)
print(f'lenth of ride data  now: {len(df_ride_data)}')

df_ride_data.head()                 
                        
# Combine the data into a single dataset
df_merged_city_ride = pd.merge(df_city_data, df_ride_data, on="city", suffixes=("_City", "_Ride"))
df_merged_city_ride_type = pd.merge(df_city_data, df_ride_data, on="city", suffixes=("_City", "_Ride"))    
df_merged_city_ride_for_bubble = pd.merge(df_city_data, df_ride_data, on="city", suffixes=("_City", "_Ride")) 
print(f'length of merged city ride data: {len(df_merged_city_ride)}')
# Display the data table for preview
df_merged_city_ride.head()
#df_merged_city_ride_type.head()
# Out:
# lenth of city data: 120
# lenth of city data  now: 120
# lenth of ride data: 2375
# lenth of ride data  now: 2375
# length of merged city ride data: 2375
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %%
#df_merged_city_ride.sort_values(by='city', inplace=True)
df_merged_city_ride_indexed=df_merged_city_ride.set_index('city')
#df_merged_city_ride_indexed
df_merged_city_ride_indexed.sort_values('city', inplace=True)
df_merged_city_ride_indexed_grouped = df_merged_city_ride_indexed.groupby('city')
df_merged_city_ride_indexed_grouped.head()
# Out:
#                      driver_count      type                 date   fare  \
# city
# Amandaburgh                    12     Urban  2018-01-11 02:22:07  29.24
# Amandaburgh                    12     Urban  2018-02-10 20:42:46  36.17
# Amandaburgh                    12     Urban  2018-03-13 12:52:31  13.88
# Amandaburgh                    12     Urban  2018-01-21 04:12:54   9.26
# Amandaburgh                    12     Urban  2018-04-19 16:30:12   6.27
# Barajasview                    26     Urban  2018-04-09 08:10:39  39.36
# Barajasview                    26     Urban  2018-01-15 02:59:07  19.52
# Barajasview                    26     Urban  2018-01-23 13:23:53  37.68
# Barajasview                    26     Urban  2018-02-08 18:07:22  24.49
# Barajasview                    26     Urban  2018-03-01 11:06:21  28.25
# Barronchester                  11  Suburban  2018-04-28 11:49:26  39.19
# Barronchester                  11  Suburban  2018-03-20 18:52:21  35.09
# ...

# %%
print("here")
# Out:
# here

# %%
print("pie: % of Total Fares by City Type")
# Out:
# pie: % of Total Fares by City Type

# %%
# pie: % of Total Fares by City Type
df_merged_city_ride_type_indexed = df_merged_city_ride_type.sort_values('type')
cityTypes = df_merged_city_ride_type_indexed['type'].unique().tolist()
print(f'City Types: {cityTypes}')
colors = ['Gold', 'skyBlue', 'Coral']
print(f'Color: {colors}')
explode = (0, 0, 0.1)

#df_merged_city_ride_type_indexed_grouped = df_merged_city_ride_type_indexed.groupby('type')
#df_merged_city_ride_type_indexed_grouped
totalFareByType = df_merged_city_ride_type_indexed.groupby('type')['fare'].sum().tolist()
print(f'totalFareByType: {totalFareByType}')
# Out:
# City Types: ['Rural', 'Suburban', 'Urban']
# Color: ['Gold', 'skyBlue', 'Coral']
# totalFareByType: [4327.929999999999, 19356.330000000005, 39854.38000000003]

# %%
plt.pie(totalFareByType, explode=explode, labels=cityTypes, colors=colors, autopct="%1.1f%%", shadow=True, startangle=150)
plt.title("% of Total Fares by City Type")
plt.savefig("./output/percent_of_total_fares_by_city_type.png")
plt.show()

# %%
plt.axis("equal")
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %%
print("pie: % of Total Rides by City Type")
# Out:
# pie: % of Total Rides by City Type

# %%
# pie: % of Total Rides by City Type
#df_merged_city_ride_type_indexed = df_merged_city_ride_type.sort_values('type')
#cityTypes = df.merged_city_ride_type_indexed['type'].unique().tolist()
print(f'City Types: {cityTypes}')
#colors = ['Gold', 'skyBlue"', 'Coral']
print(f'Color: {colors}')
explode = (0, 0, 0.1)

#df_merged_city_ride_type_indexed_grouped = df_merged_city_ride_type_indexed.groupby('type')
#df_merged_city_ride_type_indexed_grouped
totalRideByType = df_merged_city_ride_type_indexed.groupby('type')['ride_id'].count().tolist()
print(f'totalRideByType: {totalRideByType}')
# Out:
# City Types: ['Rural', 'Suburban', 'Urban']
# Color: ['Gold', 'skyBlue', 'Coral']
# totalRideByType: [125, 625, 1625]

# %%
plt.pie(totalRideByType, explode=explode, labels=cityTypes, colors=colors, autopct="%1.1f%%", shadow=True, startangle=150)
plt.title("% of Total Rides by City Type")
plt.savefig("./output/percent_of_total_rides_by_city_type.png")
plt.show()

# %%
plt.axis("equal")
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %%
print("here - pie - total driver counts by city ")
# Out:
# here - pie - total driver counts by city

# %%
# pie: % of Total Drivers by City Type
df_city_data_for_type_driver.sort_values("type", inplace=True)
#cityTypes = df.merged_city_ride_type_indexed['type'].unique().tolist()
print(f'City Types: {cityTypes}')
#colors = ['Gold', 'skyBlue"', 'Coral']
print(f'Color: {colors}')
explode = (0, 0, 0.1)

#df_merged_city_ride_type_indexed_grouped = df_merged_city_ride_type_indexed.groupby('type')
#df_merged_city_ride_type_indexed_grouped
totalDriverCountByType = df_city_data_for_type_driver.groupby('type')['driver_count'].sum().tolist()
print(f'totalDriverCountByType: {totalDriverCountByType}')
# Out:
# City Types: ['Rural', 'Suburban', 'Urban']
# Color: ['Gold', 'skyBlue', 'Coral']
# totalDriverCountByType: [78, 490, 2405]

# %%
plt.pie(totalDriverCountByType, explode=explode, labels=cityTypes, colors=colors, autopct="%1.1f%%", shadow=True, startangle=170)
plt.title("% of Total Drivers by City Type")
plt.savefig("./output/percent_of_total_drivers_by_city_type.png")
plt.show()

# %%
plt.axis("equal")
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %%
print("Bubble chart")
# Out:
# Bubble chart

# %%
### Bubble Chart
df_city_data_for_bubble.sort_values('city', inplace=True)
#df_city_data_for_bubble.head()

### add column "color" to city data
colordict = dict(zip(cityTypes, colors))
print(f'{colordict}')   
df_city_data_for_bubble["color"] = df_city_data_for_bubble['type'].apply(lambda x: colordict[x])
#df_merged_city_ride_type['type'].apply(lambda x: colordict[x])
###df_city_data_for_bubble.head()

###
#bubbleColors= df_city_data_for_bubble["color"].tolist()


###m merge averageFare and totalRide
df_merged_city_ride_for_bubble.sort_values('city', inplace=True)
#df_merged_city_ride_for_bubble.head()

df_city_averagefare = df_merged_city_ride_for_bubble.groupby('city')['fare'].mean()
#df_city_averagefare.head()

df_city_totalrides = df_merged_city_ride_for_bubble.groupby('city')['ride_id'].count()
#df_city_totalrides.head()

df_bubble_city_fare = pd.merge(df_city_data_for_bubble, df_city_averagefare, on="city")
#df_bubble_city_fare.head()
df_bubble_city_fare_ride = pd.merge(df_bubble_city_fare, df_city_totalrides, on="city")
#df_bubble_city_fare_ride.head()
df_bubble_city_fare_ride.rename(columns={"fare" : "average_fare", "ride_id": "total_rides"}, inplace=True)
df_bubble_city_fare_ride.head()


cities = df_bubble_city_fare_ride["city"].to_list()
#print(f'city: {cities}')

types = df_bubble_city_fare_ride["type"].to_list()
### Bubble Chart
df_city_data_for_bubble.sort_values('city', inplace=True)
#df_city_data_for_bubble.head()

### add column "color" to city data
colordict = dict(zip(cityTypes, colors))
print(f'{colordict}')   
df_city_data_for_bubble["color"] = df_city_data_for_bubble['type'].apply(lambda x: colordict[x])
#df_merged_city_ride_type['type'].apply(lambda x: colordict[x])
###df_city_data_for_bubble.head()

###
#bubbleColors= df_city_data_for_bubble["color"].tolist()


###m merge averageFare and totalRide
df_merged_city_ride_for_bubble.sort_values('city', inplace=True)
#df_merged_city_ride_for_bubble.head()

df_city_averagefare = df_merged_city_ride_for_bubble.groupby('city')['fare'].mean()
#df_city_averagefare.head()

df_city_totalrides = df_merged_city_ride_for_bubble.groupby('city')['ride_id'].count()
#df_city_totalrides.head()

df_bubble_city_fare = pd.merge(df_city_data_for_bubble, df_city_averagefare, on="city")
#df_bubble_city_fare.head()
df_bubble_city_fare_ride = pd.merge(df_bubble_city_fare, df_city_totalrides, on="city")
#df_bubble_city_fare_ride.head()
df_bubble_city_fare_ride.rename(columns={"fare" : "average_fare", "ride_id": "total_rides"}, inplace=True)
df_bubble_city_fare_ride.head()


cities = df_bubble_city_fare_ride["city"].to_list()
#print(f'city: {cities}')

types = df_bubble_city_fare_ride["type"].to_list()
#print(f'type: {types}')

driverCountsCity = (df_bubble_city_fare_ride["driver_count"]*10).tolist()
#print(f'driver count: {driverCountCity}')

averageFareCity= df_bubble_city_fare_ride["average_fare"].tolist()
#print(f'average fare: {averageFareCity=}')

totalRidesCity = df_bubble_city_fare_ride["total_rides"].tolist()
#print(f'total ride: {totalRideCity}')

cityTypeColor = df_bubble_city_fare_ride["color"].tolist()
#print(f'color: {cityTypeColor}')
# Out:
# {'Rural': 'Gold', 'Suburban': 'skyBlue', 'Urban': 'Coral'}
# {'Rural': 'Gold', 'Suburban': 'skyBlue', 'Urban': 'Coral'}

# %%
# Create a legend for our chart
#### legend

type_list = list(df_bubble_city_fare_ride['type'].unique())
color_list = list(df_bubble_city_fare_ride['color'].unique())
l = []

for i in range(0, len(type_list)):
  
   l.append(patches.Patch(color = color_list[i],
                           alpha = 0.5,
                           label = type_list[i]))

#plt.legend(handles=l, loc=(1.05,0))
plt.legend(handles=l, loc="best")

# %%
plt.scatter(x=totalRidesCity, y=averageFareCity, s=driverCountsCity, c=cityTypeColor, alpha=0.5, edgecolors='black', linewidth=1)
plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")

# Create a legend for our chart
#### legend

type_list = list(df_bubble_city_fare_ride['type'].unique())
color_list = list(df_bubble_city_fare_ride['color'].unique())
l = []

for i in range(0, len(type_list)):
  
   l.append(patches.Patch(color = color_list[i],
                           alpha = 0.5,
                           label = type_list[i]))


plt.legend(handles=l, loc="best")
#plt.legend(handles=l, loc=(1.05,0))
#plt.legend(handles=l, loc=(0.70,0.70))
plt.savefig("./output/pyber_ride_sharing_data_2016.png")

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types

# Build the scatter plots for each city types

# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents

# Build Pie Charts

# Save Figure

# %%
# Show Figure
plt.show()
